# %%
import pandas as pd
import numpy as np

# %%
from recommender import Recommender

# %%
rec = Recommender()

# %%
rec.fit('../data/train_data.csv','../data/movies_clean.csv', iters=300)
# Out:
# Optimizaiton Statistics: iter 0
# Mean Squared Error nan
# c:\Users\Pontello\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\Pontello\anaconda3\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Optimizaiton Statistics: iter 1
# Mean Squared Error 21.867496985411535
# Optimizaiton Statistics: iter 2
# Mean Squared Error 20.858371583906926
# Optimizaiton Statistics: iter 3
# Mean Squared Error 19.993682006731582
# Optimizaiton Statistics: iter 4
# Mean Squared Error 19.242829055979957
# Optimizaiton Statistics: iter 5
# Mean Squared Error 18.582635655846182
# Optimizaiton Statistics: iter 6
# Mean Squared Error 17.995445390070127
# Optimizaiton Statistics: iter 7
# Mean Squared Error 17.467727925436485
# Optimizaiton Statistics: iter 8
# Mean Squared Error 16.98904722420327
# ...

# %%
rec.n_users
# Out:
# 3278

# %%
rec.n_movies
# Out:
# 2679

# %%
rec.make_recommendations(_id = 37287, _id_type= 'user')
# Out:
# (array([1853728,  454876,  111161, 1675434,  780504], dtype=int64),
#  ['The Shawshank Redemption (1994)',
#   'Life of Pi (2012)',
#   'Drive (2011)',
#   'The Intouchables (2011)',
#   'Django Unchained (2012)'])

# %%
rec.make_recommendations(_id = 38, _id_type= 'user')
# Out:
# Because this user wasn't in our database, we are giving back the top movie recommendations for all users.
# (None,
#  ['Goodfellas (1990)',
#   'Step Brothers (2008)',
#   'American Beauty (1999)',
#   'There Will Be Blood (2007)',
#   'Gran Torino (2008)'])
